# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath(".."))  

from models.KNN import run_knn_train_test, save_model_KNN, load_model_KNN, plot_accuracy_vs_k, plot_confusion_matrix

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))  
csv_path = os.path.join(project_root, "..", "data", "IRIS_cleaned.csv") 

df = pd.read_csv(csv_path)
print("Shape of dataset:", df.shape)
print(df.head())

train_results, best_k, train_acc, test_acc, model, y_true, y_pred = run_knn_train_test(
    df, test_size=0.2
)



model_path = os.path.join(project_root, "models", "knn_model.pkl")
save_model_KNN(model, model_path)
print(f"Model saved to {model_path}")
# Out:
# Shape of dataset: (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0      0.222222     0.625000      0.067797     0.041667  Iris-setosa
# 1      0.166667     0.416667      0.067797     0.041667  Iris-setosa
# 2      0.111111     0.500000      0.050847     0.041667  Iris-setosa
# 3      0.083333     0.458333      0.084746     0.041667  Iris-setosa
# 4      0.194444     0.666667      0.067797     0.041667  Iris-setosa
# Chọn K bằng 5-Fold Cross-Validation trên tập train:
#   k |   Accuracy (CV)
# -------------------------
#   1 |          0.9417
#   2 |          0.9417
#   3 |          0.9500
#   4 |          0.9500
#   5 |          0.9500
#   6 |          0.9583
#   7 |          0.9583
#   8 |          0.9583
#   9 |          0.9583
#  10 |          0.9583
#  11 |          0.9667
#  12 |          0.9583
#  13 |          0.9583
#  14 |          0.9583
#  15 |          0.9667
#  16 |          0.9583
#  17 |          0.9500
#  18 |          0.9500
# ...

# %%
plot_accuracy_vs_k(train_results, best_k)

# %%
class_labels = sorted(df["species"].unique())
plot_confusion_matrix(y_true, y_pred, class_labels)
